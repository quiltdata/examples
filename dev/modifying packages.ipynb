# %%
# !quilt install akarve/wine --force
# !quilt install akarve/examples --force
# !quilt install akarve/clinton_email --force
# Out:
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.
# ...
# Fragment already installed; skipping.

# %%
from quilt.data.akarve import wine, examples, clinton_email

# %%
wine
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/wine'>
# README
# quality

# %%
wine.quality
# Out:
# <GroupNode>
# red
# white

# %%
wine.quality.red = wine.quality.white

# %%
wine.quality.white() == wine.quality.red()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 4              True              True         True            True       True
# 5              True              True         True            True       True
# 6              True              True         True            True       True
# 7              True              True         True            True       True
# 8              True              True         True            True       True
# 9              True              True         True            True       True
# 10             True              True         True            True       True
# ...

# %%
import quilt

# %%
quilt.build("akarve/winesame", wine)

# %%
from quilt.data.akarve import winesame

# %%
winesame
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/winesame'>
# README
# quality

# %%
winesame.quality
# Out:
# <GroupNode>
# red
# white

# %%
winesame.quality.red() == winesame.quality.white()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 4              True              True         True            True       True
# 5              True              True         True            True       True
# 6              True              True         True            True       True
# 7              True              True         True            True       True
# 8              True              True         True            True       True
# 9              True              True         True            True       True
# 10             True              True         True            True       True
# ...

# %%
clinton_email
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/clinton_email'>
# README
# database
# emailReceivers
# emails
# hashes
# persons

# %%
clinton_email.aliases = None

# %%
clinton_email
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/clinton_email'>
# README
# aliases
# database
# emailReceivers
# emails
# hashes
# persons

# %%
clinton_email.aliases

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

# %%
# clinton_email.aliases = df
del clinton_email.aliases

# %%
clinton_email
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/clinton_email'>
# README
# database
# emailReceivers
# emails
# hashes
# persons

# %%
quilt.build("akarve/clinton_scrubbed", clinton_email)

# %%
from quilt.data.akarve import clinton_scrubbed

# %%
clinton_scrubbed
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/clinton_scrubbed'>
# README
# database
# emailReceivers
# emails
# hashes
# persons

# %%
winesame
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/winesame'>
# README
# quality

# %%
new_cols = ["column_%s" % x for x in range(len(winesame.quality.red().columns))]

# %% [markdown]
# # unable to reassign column names

# %%
winesame.quality.red().columns = new_cols

# %%
winesame.quality.red()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
df.columns = [1, 2, 3, 4]

# %%
df
# Out:
#      1   2   3   4
# 0   60   7  87  73
# 1   61  69  53  20
# 2   40  52  45  35
# 3   11  91  52  82
# 4   45  75  88  87
# 5   12  34  94  26
# 6   42  54  21  91
# 7   76   0  78  15
# 8   63  37  86  51
# 9    2  30  76  10
# 10  11  27  61  53
# 11  23  11  60  53
# 12  12  68  27  14
# 13  16  54  72  17
# 14  87  62  12  61
# 15   5  48  71  55
# 16  96  27  24  89
# 17  44  16  40  61
# 18  94  23  95  36
# 19  84  94  22  58
# 20  37  60  75  23
# 21  24  63  90  94
# 22  53  34  17  98
# 23  63   5  10  78
# 24  72  86  56  37
# 25  25  51  84  84
# 26  74  79  36  42
# 27  14   3  53  60
# 28  80   9   9   8
# 29  54  93  78  59
# ..  ..  ..  ..  ..
# 70  31  11   1   7
# 71  26  39  68  17
# 72   4   0  80  92
# 73  99  68  82  77
# 74  21  15  27  72
# 75  83  40  62   1
# 76  44  91   7  29
# 77  86   5  18  75
# 78  32  85  30  48
# 79  97   7  40  88
# 80  33  60  35  71
# 81  50  77   6  42
# 82  95  36  79  89
# 83  64  61  14  80
# 84  96  43  12  97
# ...

# %%
df.set_value(1, 1, 2048)
# Out:
#        1   2   3   4
# 0     60   7  87  73
# 1   2048  69  53  20
# 2     40  52  45  35
# 3     11  91  52  82
# 4     45  75  88  87
# 5     12  34  94  26
# 6     42  54  21  91
# 7     76   0  78  15
# 8     63  37  86  51
# 9      2  30  76  10
# 10    11  27  61  53
# 11    23  11  60  53
# 12    12  68  27  14
# 13    16  54  72  17
# 14    87  62  12  61
# 15     5  48  71  55
# 16    96  27  24  89
# 17    44  16  40  61
# 18    94  23  95  36
# 19    84  94  22  58
# 20    37  60  75  23
# 21    24  63  90  94
# 22    53  34  17  98
# 23    63   5  10  78
# 24    72  86  56  37
# 25    25  51  84  84
# 26    74  79  36  42
# 27    14   3  53  60
# 28    80   9   9   8
# 29    54  93  78  59
# ..   ...  ..  ..  ..
# 70    31  11   1   7
# 71    26  39  68  17
# 72     4   0  80  92
# 73    99  68  82  77
# 74    21  15  27  72
# 75    83  40  62   1
# 76    44  91   7  29
# 77    86   5  18  75
# 78    32  85  30  48
# 79    97   7  40  88
# 80    33  60  35  71
# ...

# %%
winesame.quality.red().set_value(0, 'fixed acidity', 100)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             100.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...

# %%
quilt.build('akarve/winecell', winesame)

# %%
from quilt.data.akarve import winecell

# %%
winecell
# Out:
# <PackageNode '/Users/karve/code/dsci/build/quilt_packages/akarve/winecell'>
# README
# quality

# %%
winecell.quality.red()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36           20.70      0.045
# 1               6.3             0.300         0.34            1.60      0.049
# 2               8.1             0.280         0.40            6.90      0.050
# 3               7.2             0.230         0.32            8.50      0.058
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 6               6.2             0.320         0.16            7.00      0.045
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 9               8.1             0.220         0.43            1.50      0.044
# 10              8.1             0.270         0.41            1.45      0.033
# ...
