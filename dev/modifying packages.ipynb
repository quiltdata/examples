# %%
# !quilt install akarve/wine --force
# !quilt install akarve/examples --force
# !quilt install akarve/clinton_email --force

# %%
from quilt.data.akarve import wine, examples, clinton_email

# %%
wine
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/wine'>
# README
# quality

# %%
wine.quality
# Out:
# <GroupNode>
# red
# white

# %%
wine.quality.red = wine.quality.white

# %%
wine.quality.white() == wine.quality.red()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 4              True              True         True            True       True
# 5              True              True         True            True       True
# 6              True              True         True            True       True
# 7              True              True         True            True       True
# 8              True              True         True            True       True
# 9              True              True         True            True       True
# 10             True              True         True            True       True
# ...

# %%
import quilt

# %%
quilt.build("akarve/winesame", wine)

# %%
from quilt.data.akarve import winesame

# %%
winesame
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/winesame'>
# README
# quality

# %%
winesame.quality
# Out:
# <GroupNode>
# red
# white

# %%
winesame.quality.red() == winesame.quality.white()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              True              True         True            True       True
# 1              True              True         True            True       True
# 2              True              True         True            True       True
# 3              True              True         True            True       True
# 4              True              True         True            True       True
# 5              True              True         True            True       True
# 6              True              True         True            True       True
# 7              True              True         True            True       True
# 8              True              True         True            True       True
# 9              True              True         True            True       True
# 10             True              True         True            True       True
# ...

# %%
clinton_email
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/clinton_email'>
# README
# aliases
# database
# emailReceivers
# emails
# hashes
# persons

# %%
del clinton_email.README

# %%
clinton_email
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/clinton_email'>
# aliases
# database
# emailReceivers
# emails
# hashes
# persons

# %%
quilt.build("akarve/clinton_scrubbed", clinton_email)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-e690a7b70a3d> in <module>()
# ----> 1 quilt.build("akarve/clinton_scrubbed", clinton_email)
#
# /Users/karve/code/quilt/quilt/tools/command.py in build(package, path_or_node)
#     210     """
#     211     if isinstance(path_or_node, data.PackageNode):
# --> 212         build_from_node(package, path_or_node)
#     213     elif isinstance(path_or_node, string_types):
#     214         build_from_path(package, path_or_node)
#
# /Users/karve/code/quilt/quilt/tools/command.py in build_from_node(package, node)
#     244             assert False, "Unexpected node type: %r" % node
#     245
# --> 246     _process_node(node)
#     247     package_obj.save_contents()
#     248
#
# /Users/karve/code/quilt/quilt/tools/command.py in _process_node(node, path)
#     228         if isinstance(node, data.GroupNode):
# ...

# %%
from quilt.data.akarve import clinton_scrubbed
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-1f452816456a> in <module>()
# ----> 1 from quilt.data.akarve import clinton_scrubbed
#
# ImportError: cannot import name 'clinton_scrubbed'

# %%
clinton_scrubbed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-e827d76359d8> in <module>()
# ----> 1 clinton_scrubbed
#
# NameError: name 'clinton_scrubbed' is not defined

# %%
import numpy as np
import pandas as pd

# %%
winesame
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/winesame'>
# README
# quality

# %%
new_cols = ["column_%s" % x for x in range(len(winesame.quality.red().columns))]

# %%
winesame.quality.red().columns = new_cols

# %%
winesame.quality.red()
# Out:
#       column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# 0          7.0     0.270      0.36     20.70     0.045      45.0     170.0
# 1          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 2          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 3          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 4          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 5          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 6          6.2     0.320      0.16      7.00     0.045      30.0     136.0
# 7          7.0     0.270      0.36     20.70     0.045      45.0     170.0
# 8          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 9          8.1     0.220      0.43      1.50     0.044      28.0     129.0
# 10         8.1     0.270      0.41      1.45     0.033      11.0      63.0
# ...

# %%
winesame.quality.red().set_value(0, 'column_0', 100)
# Out:
#       column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# 0        100.0     0.270      0.36     20.70     0.045      45.0     170.0
# 1          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 2          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 3          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 4          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 5          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 6          6.2     0.320      0.16      7.00     0.045      30.0     136.0
# 7          7.0     0.270      0.36     20.70     0.045      45.0     170.0
# 8          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 9          8.1     0.220      0.43      1.50     0.044      28.0     129.0
# 10         8.1     0.270      0.41      1.45     0.033      11.0      63.0
# ...

# %%
quilt.build('akarve/winecell', winesame)

# %%
from quilt.data.akarve import winecell

# %%
winecell
# Out:
# <PackageNode '/Users/karve/code/examples/dev/quilt_packages/akarve/winecell'>
# README
# quality

# %%
winecell.quality.red()
# Out:
#       column_0  column_1  column_2  column_3  column_4  column_5  column_6  \
# 0        100.0     0.270      0.36     20.70     0.045      45.0     170.0
# 1          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 2          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 3          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 4          7.2     0.230      0.32      8.50     0.058      47.0     186.0
# 5          8.1     0.280      0.40      6.90     0.050      30.0      97.0
# 6          6.2     0.320      0.16      7.00     0.045      30.0     136.0
# 7          7.0     0.270      0.36     20.70     0.045      45.0     170.0
# 8          6.3     0.300      0.34      1.60     0.049      14.0     132.0
# 9          8.1     0.220      0.43      1.50     0.044      28.0     129.0
# 10         8.1     0.270      0.41      1.45     0.033      11.0      63.0
# ...
