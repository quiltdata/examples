# %%
from scipy.io import loadmat

from quilt.data.kmoore import sat4_6_airborne as sa

# %%
mat = loadmat(sa.sat_6_full())

# %%
mat['test_x']
# Out:
# array([[[[ 95, 102,  47, ..., 140,  89,  30],
#          [ 91, 102,  54, ..., 136,  87,  26],
#          [ 61, 103,  95, ..., 126,  99,  29],
#          [157, 137,  10, ..., 190,  13,  44]],
#
#         [[105, 108,  79, ..., 156,  64,  29],
#          [113, 110,  89, ..., 163,  66,  22],
#          [101, 116, 108, ..., 152,  89,  29],
#          [179, 154,  15, ..., 208,   9,  26]],
#
#         [[ 50,  88,  96, ..., 152,  16,  40],
#          [ 35,  83, 131, ..., 170,  26,  31],
#          [ 24,  70, 118, ..., 149,  65,  45],
#          [124, 122,  23, ..., 205,   4,  25]],
#
#         ...,
#
#         [[ 54,  91,  45, ...,  80, 103, 124],
#          [ 56,  89,  62, ...,  93, 109, 118],
#          [ 35,  92,  91, ...,  92, 125, 107],
#          [128, 110,   9, ..., 160,  25, 163]],
#
#         [[ 72,  96,  38, ...,  65, 124, 115],
#          [ 82,  96,  45, ...,  63, 139, 105],
#          [ 80, 100,  87, ...,  44, 130,  93],
#          [149, 118,   8, ..., 124,  33, 156]],
#
# ...
